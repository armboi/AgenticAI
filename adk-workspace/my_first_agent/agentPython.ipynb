# %%
pip install google-adk python-dotenv
# Out:
# Requirement already satisfied: google-adk in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (1.31.0)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (0.22.1)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (4.13.0)
# Requirement already satisfied: authlib<2.0.0,>=1.6.6 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.7.0)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (8.3.2)
# Requirement already satisfied: fastapi<1.0.0,>=0.124.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (0.136.0)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.194.0)
# Requirement already satisfied: google-auth>=2.47.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk) (2.49.2)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.148.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (1.148.1)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.37.0)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (3.41.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.36.0)
# Requirement already satisfied: google-cloud-dataplex<3.0.0,>=1.7.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.18.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-pubsub<3.0.0,>=2.0.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.37.0)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.27.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (3.65.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.38.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (3.10.1)
# Requirement already satisfied: google-genai<2.0.0,>=1.72.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.73.1)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (0.21)
# Requirement already satisfied: httpx<1.0.0,>=0.27.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (0.28.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.24.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.27.0)
# Requirement already satisfied: opentelemetry-api<1.39.0,>=1.36.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<1.39.0,>=1.36.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: pyarrow>=14.0.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (23.0.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.13.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.33.1)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (1.17.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (2.0.49)
# Requirement already satisfied: starlette<1.0.0,>=0.49.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (0.52.1)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (9.1.4)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (0.44.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: cryptography in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from authlib<2.0.0,>=1.6.6->google-adk) (46.0.7)
# Requirement already satisfied: joserfc>=1.6.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from authlib<2.0.0,>=1.6.6->google-adk) (1.6.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.124.1->google-adk) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.124.1->google-adk) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.3.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.30.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.74.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.27.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk) (0.4.2)
# Requirement already satisfied: packaging>=14.3 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.148.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (26.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.148.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (1.17.0)
# Requirement already satisfied: docstring_parser<1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.148.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (0.18.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.148.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.148.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (1.80.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (1.19.0)
# Requirement already satisfied: google-cloud-logging<4 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (3.15.0)
# Requirement already satisfied: google-cloud-iam in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (2.22.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (3.13.5)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-dataplex<3.0.0,>=1.7.0->google-adk) (0.14.4)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (1.9.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (0.5.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.5)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.43b0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.59b0)
# Requirement already satisfied: google-cloud-monitoring>=2.16.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (2.30.0)
# Requirement already satisfied: mmh3>=4.1.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (5.2.1)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-cloud-storage<4.0.0,>=2.18.0->google-adk) (1.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.72.0->google-adk) (1.9.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.72.0->google-adk) (1.3.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.3.2)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from httpx<1.0.0,>=0.27.0->google-adk) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from httpx<1.0.0,>=0.27.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.0->google-adk) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.30.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from mcp<2.0.0,>=1.24.0->google-adk) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from mcp<2.0.0,>=1.24.0->google-adk) (2.14.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->google-adk) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from mcp<2.0.0,>=1.24.0->google-adk) (0.0.26)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from mcp<2.0.0,>=1.24.0->google-adk) (3.3.4)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from opentelemetry-api<1.39.0,>=1.36.0->google-adk) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<1.39.0,>=1.36.0->google-adk) (3.23.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.38.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.12.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.12.0->google-adk) (2.46.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from cryptography->authlib<2.0.0,>=1.6.6->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.6.6->google-adk) (3.0)
# Requirement already satisfied: pyopenssl>=20.0.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk) (26.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk) (0.6.3)
# Requirement already satisfied: alembic in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.18.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.0->google-adk) (1.23.0)
# Requirement already satisfied: Mako in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.11)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/anaconda3/envs/ADK-Workspace/lib/python3.12/site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv('/Users/manojsinghadhikari/Documents/Job Change/AgenticAI/adk-workspace/my_first_agent/.env')
# Out:
# True

# %%
import asyncio
from google.adk.agents.llm_agent import Agent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.genai.types import Content, Part

# %%
agent = Agent(
    model='gemini-2.5-flash',
    name='math_tutor',
    instruction="""You are a patient math tutor.
    Guide students through problems step-by-step.
    Don't just give answers - help them discover solutions."""
)

APP_NAME = "math_tutor_app"
USER_ID = "student_1"
SESSION_ID = "session_004"

session_service = InMemorySessionService()
runner = Runner(
    agent=agent,
    app_name=APP_NAME,
    session_service=session_service
)

# %%
async def run_agent(question):
    session = await session_service.create_session(
        app_name=APP_NAME,
        user_id=USER_ID,
        session_id=SESSION_ID
    )

    user_message = Content(
        role="user",
        parts=[Part(text=question)]
    )

    print(f"User: {question}\n")
    print("Agent: ", end="")

    async for event in runner.run_async(
        user_id=USER_ID,
        session_id=SESSION_ID,
        new_message=user_message
    ):
        if event.is_final_response() and event.content and event.content.parts:
            print(event.content.parts[0].text)

# %%
await run_agent("How do I solve 2x + 5 = 13?")
# Out:
# User: How do I solve 2x + 5 = 13?
#
# Agent: That's a great question! This is a common type of algebra problem where we want to find the value of an unknown, in this case, 'x'.
#
# The main idea is to isolate 'x' on one side of the equation. To do that, we need to get rid of the numbers around it.
#
# What's the first thing you think we should do to start getting 'x' by itself?

# %%
await run_agent("How do I solve x^2 + 2x + 5 = 13?")
# Out:
# User: How do I solve x^2 + 2x + 5 = 13?
#
# Agent: That's a great problem! We have a quadratic equation here.
#
# The first step when solving a quadratic equation is usually to get it into "standard form," which means having all the terms on one side and 0 on the other side.
#
# How would you go about getting `x^2 + 2x + 5 = 13` into the form `ax^2 + bx + c = 0`?
